# %% [markdown]
# #### CSC 180 Intelligent Systems
#
# #### California State University, Sacramento

# %% [markdown]
# ## Lab 7: Model Performance Visualization

# %% [markdown]
# # Helpful Functions for Tensorflow
#
# The following functions will be used with TensorFlow to help preprocess the data.  They allow you to build the feature vector for a neural network.
#
# * Predictors/Inputs
#     * Fill any missing inputs with the median for that column.  Use **missing_median**.
#     * Encode textual/categorical values with **encode_text_dummy**.
#     * Encode numeric values with **encode_numeric_zscore**.
# * Output
#     * Discard rows with missing outputs.
#     * Encode textual/categorical values with **encode_text_index**.
#     * Do not encode output numeric values.
# * Produce final feature vectors (x) and expected output (y) with **to_xy**.

# %%
from collections.abc import Sequence
from sklearn import preprocessing
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import shutil
import os


# Encode text values to dummy variables(i.e. [1,0,0],[0,1,0],[0,0,1] for red,green,blue)
def encode_text_dummy(df, name):
    dummies = pd.get_dummies(df[name])
    for x in dummies.columns:
        dummy_name = "{}-{}".format(name, x)
        df[dummy_name] = dummies[x]
    df.drop(name, axis=1, inplace=True)



# Encode text values to indexes(i.e. [1],[2],[3] for red,green,blue).
def encode_text_index(df, name):
    le = preprocessing.LabelEncoder()
    df[name] = le.fit_transform(df[name])
    return le.classes_


# Encode a numeric column as zscores
def encode_numeric_zscore(df, name, mean=None, sd=None):
    if mean is None:
        mean = df[name].mean()

    if sd is None:
        sd = df[name].std()

    df[name] = (df[name] - mean) / sd


# Convert all missing values in the specified column to the median
def missing_median(df, name):
    med = df[name].median()
    df[name] = df[name].fillna(med)


# Convert all missing values in the specified column to the default
def missing_default(df, name, default_value):
    df[name] = df[name].fillna(default_value)


# Convert a Pandas dataframe to the x,y inputs that TensorFlow needs
def to_xy(df, target):
    result = []
    for x in df.columns:
        if x != target:
            result.append(x)
    # find out the type of the target column. 
    target_type = df[target].dtypes
    target_type = target_type[0] if isinstance(target_type, Sequence) else target_type
    # Encode to int for classification, float otherwise. TensorFlow likes 32 bits.
    if target_type in (np.int64, np.int32):
        # Classification
        dummies = pd.get_dummies(df[target])
        return df[result].values.astype(np.float32), dummies.values.astype(np.float32)
    else:
        # Regression
        return df[result].values.astype(np.float32), df[target].values.astype(np.float32)

# Nicely formatted time string
def hms_string(sec_elapsed):
    h = int(sec_elapsed / (60 * 60))
    m = int((sec_elapsed % (60 * 60)) / 60)
    s = sec_elapsed % 60
    return "{}:{:>02}:{:>05.2f}".format(h, m, s)


# Regression chart.
def chart_regression(pred,y,sort=True):
    t = pd.DataFrame({'pred' : pred, 'y' : y.flatten()})
    if sort:
        t.sort_values(by=['y'],inplace=True)
    a = plt.plot(t['y'].tolist(),label='expected')
    b = plt.plot(t['pred'].tolist(),label='prediction')
    plt.ylabel('output')
    plt.legend()
    plt.show()

# Remove all rows where the specified column is +/- sd standard deviations
def remove_outliers(df, name, sd):
    drop_rows = df.index[(np.abs(df[name] - df[name].mean()) >= (sd * df[name].std()))]
    df.drop(drop_rows, axis=0, inplace=True)


# Encode a column to a range between normalized_low and normalized_high.
def encode_numeric_range(df, name, normalized_low=-1, normalized_high=1,
                         data_low=None, data_high=None):
    if data_low is None:
        data_low = min(df[name])
        data_high = max(df[name])

    df[name] = ((df[name] - data_low) / (data_high - data_low)) \
               * (normalized_high - normalized_low) + normalized_low

# %% [markdown]
# # Metrics:
#
# For any type of classification neural network:
#
# * **Accuracy**
# * **Precision**
# * **Recall**
# * **F1 Score**
# * **Log Loss**
# * **Confusion Matrix**
# * **ROC Curve**
#
# For regression neural networks:
# * **RMSE**
# * **R2 Score**
# * **Lift Chart**
#
# Check Sklearn API here http://scikit-learn.org/stable/modules/classes.html#module-sklearn.metrics
#
# The code used to produce Confusion matrix and ROC curve is shown here:

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
from sklearn.metrics import roc_curve, auc

# Plot a confusion matrix.
# cm is the confusion matrix, names are the names of the classes.
def plot_confusion_matrix(cm, names, title='Confusion matrix', cmap=plt.cm.Blues):
    plt.imshow(cm, interpolation='nearest', cmap=cmap)
    plt.title(title)
    plt.colorbar()
    tick_marks = np.arange(len(names))
    plt.xticks(tick_marks, names, rotation=45)
    plt.yticks(tick_marks, names)
    plt.tight_layout()
    plt.ylabel('True label')
    plt.xlabel('Predicted label')
    

# Plot an ROC. pred - the predictions, y - the expected output.
def plot_roc(pred,y):
    fpr, tpr, thresholds = roc_curve(y, pred)
    roc_auc = auc(fpr, tpr)

    plt.figure()
    plt.plot(fpr, tpr, label='ROC curve (area = %0.2f)' % roc_auc)
    plt.plot([0, 1], [0, 1], 'k--')
    plt.xlim([0.0, 1.0])
    plt.ylim([0.0, 1.05])
    plt.xlabel('False Positive Rate')
    plt.ylabel('True Positive Rate')
    plt.title('Receiver Operating Characteristic (ROC)')
    plt.legend(loc="lower right")
    plt.show()

# %% [markdown]
# # Visualizing binary classification models
#
#
# Binary classification is used to create a model that classifies between only two classes.  These two classes are often called "positive" and "negative".

# %%
import os
import pandas as pd
from sklearn.model_selection import train_test_split
import tensorflow as tf
import numpy as np
from sklearn import metrics
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Activation
from tensorflow.keras.callbacks import EarlyStopping
from tensorflow.keras.callbacks import ModelCheckpoint

# Set the desired TensorFlow output level for this example
# tf.logging.set_verbosity(tf.logging.ERROR)

path = "./data/"
    
filename = os.path.join(path,"wcbreast_wdbc.csv")    
df = pd.read_csv(filename,na_values=['NA','?'])
df
# Out:
#            id diagnosis  mean_radius  mean_texture  mean_perimeter  mean_area  \
# 0      842302         M        17.99         10.38          122.80     1001.0
# 1      842517         M        20.57         17.77          132.90     1326.0
# 2    84300903         M        19.69         21.25          130.00     1203.0
# 3    84348301         M        11.42         20.38           77.58      386.1
# 4    84358402         M        20.29         14.34          135.10     1297.0
# ..        ...       ...          ...           ...             ...        ...
# 564    926424         M        21.56         22.39          142.00     1479.0
# 565    926682         M        20.13         28.25          131.20     1261.0
# 566    926954         M        16.60         28.08          108.30      858.1
# 567    927241         M        20.60         29.33          140.10     1265.0
# 568     92751         B         7.76         24.54           47.92      181.0
#
#      mean_smoothness  mean_compactness  mean_concavity  mean_concave_points  \
# 0            0.11840           0.27760         0.30010              0.14710
# 1            0.08474           0.07864         0.08690              0.07017
# 2            0.10960           0.15990         0.19740              0.12790
# 3            0.14250           0.28390         0.24140              0.10520
# 4            0.10030           0.13280         0.19800              0.10430
# ..               ...               ...             ...                  ...
# 564          0.11100           0.11590         0.24390              0.13890
# 565          0.09780           0.10340         0.14400              0.09791
# 566          0.08455           0.10230         0.09251              0.05302
# 567          0.11780           0.27700         0.35140              0.15200
# 568          0.05263           0.04362         0.00000              0.00000
#
#      ...  worst_radius  worst_texture  worst_perimeter  worst_area  \
# 0    ...        25.380          17.33           184.60      2019.0
# 1    ...        24.990          23.41           158.80      1956.0
# 2    ...        23.570          25.53           152.50      1709.0
# 3    ...        14.910          26.50            98.87       567.7
# 4    ...        22.540          16.67           152.20      1575.0
# ..   ...           ...            ...              ...         ...
# 564  ...        25.450          26.40           166.10      2027.0
# 565  ...        23.690          38.25           155.00      1731.0
# 566  ...        18.980          34.12           126.70      1124.0
# 567  ...        25.740          39.42           184.60      1821.0
# 568  ...         9.456          30.37            59.16       268.6
#
#      worst_smoothness  worst_compactness  worst_concavity  \
# 0             0.16220            0.66560           0.7119
# 1             0.12380            0.18660           0.2416
# 2             0.14440            0.42450           0.4504
# 3             0.20980            0.86630           0.6869
# 4             0.13740            0.20500           0.4000
# ..                ...                ...              ...
# 564           0.14100            0.21130           0.4107
# 565           0.11660            0.19220           0.3215
# 566           0.11390            0.30940           0.3403
# 567           0.16500            0.86810           0.9387
# 568           0.08996            0.06444           0.0000
#
#      worst_concave_points  worst_symmetry  worst_fractal_dimension
# 0                  0.2654          0.4601                  0.11890
# 1                  0.1860          0.2750                  0.08902
# 2                  0.2430          0.3613                  0.08758
# 3                  0.2575          0.6638                  0.17300
# 4                  0.1625          0.2364                  0.07678
# ..                    ...             ...                      ...
# 564                0.2216          0.2060                  0.07115
# 565                0.1628          0.2572                  0.06637
# 566                0.1418          0.2218                  0.07820
# 567                0.2650          0.4087                  0.12400
# 568                0.0000          0.2871                  0.07039
#
# [569 rows x 32 columns]

# %%
# Encode feature vector
df.drop('id',axis=1,inplace=True)

diagnosis = encode_text_index(df,'diagnosis')

# Create x & y for training and testing
x, y = to_xy(df,'diagnosis')
    
# Split into train/test
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.25, random_state=42)

# %% [markdown]
# ### Best practice!! Avoid local optimum by using a loop to initialize the same model multiple times!!

# %%
# Define ModelCheckpoint outside the loop
checkpointer = ModelCheckpoint(filepath="dnn/best_weights.hdf5", verbose=0, save_best_only=True) # save best model

for i in range(5):
    print(i)

    # Build network
    model = Sequential()
    model.add(Dense(20, input_dim=x.shape[1], activation='relu'))
    model.add(Dense(10, activation='relu'))
    model.add(Dense(y.shape[1], activation='softmax'))
    model.compile(loss='categorical_crossentropy', optimizer='adam')

    monitor = EarlyStopping(monitor='val_loss', min_delta=1e-3, patience=5, verbose=1, mode='auto')

    model.fit(x_train,y_train,validation_data=(x_test,y_test),callbacks=[monitor,checkpointer],verbose=2,epochs=100)


print('Training finished...Loading the best model')  
print()
model.load_weights('dnn/best_weights.hdf5') # load weights from best model

# Measure accuracy
pred = model.predict(x_test)
pred = np.argmax(pred,axis=1)

y_true = np.argmax(y_test,axis=1)

score = metrics.accuracy_score(y_true, pred)
print("Final accuracy: {}".format(score))
# Out:
# 0
# Epoch 1/100
# 14/14 - 1s - loss: 130.9921 - val_loss: 77.0752 - 522ms/epoch - 37ms/step
# Epoch 2/100
# 14/14 - 0s - loss: 43.7173 - val_loss: 22.2064 - 41ms/epoch - 3ms/step
# Epoch 3/100
# 14/14 - 0s - loss: 18.9918 - val_loss: 15.6872 - 41ms/epoch - 3ms/step
# Epoch 4/100
# 14/14 - 0s - loss: 13.5384 - val_loss: 13.4227 - 41ms/epoch - 3ms/step
# Epoch 5/100
# 14/14 - 0s - loss: 10.6069 - val_loss: 9.4330 - 42ms/epoch - 3ms/step
# Epoch 6/100
# c:\Users\cdub6\anaconda3\Lib\site-packages\keras\src\engine\training.py:3103: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
# 14/14 - 0s - loss: 7.2401 - val_loss: 5.4517 - 41ms/epoch - 3ms/step
# Epoch 7/100
# 14/14 - 0s - loss: 3.7723 - val_loss: 2.4067 - 42ms/epoch - 3ms/step
# Epoch 8/100
# 14/14 - 0s - loss: 1.6944 - val_loss: 1.0930 - 40ms/epoch - 3ms/step
# Epoch 9/100
# 14/14 - 0s - loss: 1.0049 - val_loss: 0.6342 - 41ms/epoch - 3ms/step
# Epoch 10/100
# 14/14 - 0s - loss: 0.7441 - val_loss: 0.4193 - 41ms/epoch - 3ms/step
# Epoch 11/100
# 14/14 - 0s - loss: 0.5060 - val_loss: 0.3170 - 42ms/epoch - 3ms/step
# Epoch 12/100
# 14/14 - 0s - loss: 0.4254 - val_loss: 0.3243 - 31ms/epoch - 2ms/step
# Epoch 13/100
# 14/14 - 0s - loss: 0.4092 - val_loss: 0.2540 - 39ms/epoch - 3ms/step
# Epoch 14/100
# 14/14 - 0s - loss: 0.3794 - val_loss: 0.2517 - 40ms/epoch - 3ms/step
# Epoch 15/100
# 14/14 - 0s - loss: 0.3985 - val_loss: 0.2453 - 40ms/epoch - 3ms/step
# Epoch 16/100
# 14/14 - 0s - loss: 0.3360 - val_loss: 0.2117 - 39ms/epoch - 3ms/step
# Epoch 17/100
# 14/14 - 0s - loss: 0.3199 - val_loss: 0.2032 - 39ms/epoch - 3ms/step
# Epoch 18/100
# 14/14 - 0s - loss: 0.3269 - val_loss: 0.2663 - 30ms/epoch - 2ms/step
# Epoch 19/100
# 14/14 - 0s - loss: 0.3355 - val_loss: 0.2012 - 39ms/epoch - 3ms/step
# Epoch 20/100
# 14/14 - 0s - loss: 0.2771 - val_loss: 0.1942 - 39ms/epoch - 3ms/step
# Epoch 21/100
# 14/14 - 0s - loss: 0.2801 - val_loss: 0.1806 - 39ms/epoch - 3ms/step
# Epoch 22/100
# 14/14 - 0s - loss: 0.2723 - val_loss: 0.1915 - 31ms/epoch - 2ms/step
# Epoch 23/100
# 14/14 - 0s - loss: 0.2906 - val_loss: 0.1896 - 30ms/epoch - 2ms/step
# Epoch 24/100
# 14/14 - 0s - loss: 0.3227 - val_loss: 0.2087 - 29ms/epoch - 2ms/step
# Epoch 25/100
# 14/14 - 0s - loss: 0.2842 - val_loss: 0.1850 - 30ms/epoch - 2ms/step
# Epoch 26/100
# 14/14 - 0s - loss: 0.2652 - val_loss: 0.1901 - 29ms/epoch - 2ms/step
# Epoch 26: early stopping
# 1
# Epoch 1/100
# 14/14 - 0s - loss: 87.9223 - val_loss: 47.2792 - 468ms/epoch - 33ms/step
# Epoch 2/100
# 14/14 - 0s - loss: 29.5424 - val_loss: 17.7958 - 33ms/epoch - 2ms/step
# Epoch 3/100
# 14/14 - 0s - loss: 14.2666 - val_loss: 8.5823 - 30ms/epoch - 2ms/step
# Epoch 4/100
# 14/14 - 0s - loss: 4.9676 - val_loss: 0.7532 - 30ms/epoch - 2ms/step
# Epoch 5/100
# 14/14 - 0s - loss: 0.6688 - val_loss: 0.6804 - 30ms/epoch - 2ms/step
# Epoch 6/100
# 14/14 - 0s - loss: 0.6779 - val_loss: 0.6797 - 31ms/epoch - 2ms/step
# Epoch 7/100
# 14/14 - 0s - loss: 0.6771 - val_loss: 0.6790 - 29ms/epoch - 2ms/step
# Epoch 8/100
# 14/14 - 0s - loss: 0.6764 - val_loss: 0.6782 - 30ms/epoch - 2ms/step
# Epoch 9/100
# 14/14 - 0s - loss: 0.6757 - val_loss: 0.6775 - 31ms/epoch - 2ms/step
# Epoch 10/100
# 14/14 - 0s - loss: 0.6749 - val_loss: 0.6770 - 29ms/epoch - 2ms/step
# Epoch 11/100
# 14/14 - 0s - loss: 0.6743 - val_loss: 0.6764 - 30ms/epoch - 2ms/step
# Epoch 12/100
# 14/14 - 0s - loss: 0.6736 - val_loss: 0.6759 - 30ms/epoch - 2ms/step
# Epoch 13/100
# 14/14 - 0s - loss: 0.6729 - val_loss: 0.6754 - 30ms/epoch - 2ms/step
# Epoch 14/100
# 14/14 - 0s - loss: 0.6723 - val_loss: 0.6749 - 30ms/epoch - 2ms/step
# Epoch 15/100
# 14/14 - 0s - loss: 0.6717 - val_loss: 0.6744 - 29ms/epoch - 2ms/step
# Epoch 16/100
# 14/14 - 0s - loss: 0.6710 - val_loss: 0.6739 - 30ms/epoch - 2ms/step
# Epoch 17/100
# 14/14 - 0s - loss: 0.6704 - val_loss: 0.6735 - 28ms/epoch - 2ms/step
# Epoch 18/100
# 14/14 - 0s - loss: 0.6697 - val_loss: 0.6730 - 29ms/epoch - 2ms/step
# Epoch 19/100
# 14/14 - 0s - loss: 0.6691 - val_loss: 0.6725 - 29ms/epoch - 2ms/step
# Epoch 20/100
# 14/14 - 0s - loss: 0.6684 - val_loss: 0.6721 - 29ms/epoch - 2ms/step
# Epoch 21/100
# 14/14 - 0s - loss: 0.6678 - val_loss: 0.6716 - 29ms/epoch - 2ms/step
# Epoch 22/100
# 14/14 - 0s - loss: 0.6671 - val_loss: 0.6712 - 35ms/epoch - 3ms/step
# Epoch 23/100
# 14/14 - 0s - loss: 0.6664 - val_loss: 0.6708 - 34ms/epoch - 2ms/step
# Epoch 24/100
# 14/14 - 0s - loss: 0.6658 - val_loss: 0.6703 - 30ms/epoch - 2ms/step
# Epoch 25/100
# 14/14 - 0s - loss: 0.6650 - val_loss: 0.6699 - 29ms/epoch - 2ms/step
# Epoch 26/100
# 14/14 - 0s - loss: 0.6644 - val_loss: 0.6694 - 31ms/epoch - 2ms/step
# Epoch 27/100
# 14/14 - 0s - loss: 0.6638 - val_loss: 0.6690 - 30ms/epoch - 2ms/step
# Epoch 28/100
# 14/14 - 0s - loss: 0.6631 - val_loss: 0.6687 - 29ms/epoch - 2ms/step
# Epoch 29/100
# 14/14 - 0s - loss: 0.6626 - val_loss: 0.6682 - 29ms/epoch - 2ms/step
# Epoch 30/100
# 14/14 - 0s - loss: 0.6618 - val_loss: 0.6678 - 30ms/epoch - 2ms/step
# Epoch 31/100
# 14/14 - 0s - loss: 0.6612 - val_loss: 0.6675 - 29ms/epoch - 2ms/step
# Epoch 32/100
# 14/14 - 0s - loss: 0.6606 - val_loss: 0.6671 - 29ms/epoch - 2ms/step
# Epoch 33/100
# 14/14 - 0s - loss: 0.6599 - val_loss: 0.6668 - 29ms/epoch - 2ms/step
# Epoch 34/100
# 14/14 - 0s - loss: 0.6594 - val_loss: 0.6664 - 29ms/epoch - 2ms/step
# Epoch 35/100
# 14/14 - 0s - loss: 0.6587 - val_loss: 0.6661 - 29ms/epoch - 2ms/step
# Epoch 36/100
# 14/14 - 0s - loss: 0.6583 - val_loss: 0.6657 - 30ms/epoch - 2ms/step
# Epoch 37/100
# 14/14 - 0s - loss: 0.6572 - val_loss: 0.6654 - 30ms/epoch - 2ms/step
# Epoch 38/100
# 14/14 - 0s - loss: 0.6566 - val_loss: 0.6651 - 28ms/epoch - 2ms/step
# Epoch 39/100
# 14/14 - 0s - loss: 0.6558 - val_loss: 0.6648 - 29ms/epoch - 2ms/step
# Epoch 40/100
# 14/14 - 0s - loss: 0.6549 - val_loss: 0.6644 - 29ms/epoch - 2ms/step
# Epoch 41/100
# 14/14 - 0s - loss: 0.6541 - val_loss: 0.6641 - 30ms/epoch - 2ms/step
# Epoch 42/100
# 14/14 - 0s - loss: 0.6532 - val_loss: 0.6639 - 29ms/epoch - 2ms/step
# Epoch 43/100
# 14/14 - 0s - loss: 0.6521 - val_loss: 0.6635 - 29ms/epoch - 2ms/step
# Epoch 44/100
# 14/14 - 0s - loss: 0.6513 - val_loss: 0.6635 - 30ms/epoch - 2ms/step
# Epoch 45/100
# 14/14 - 0s - loss: 0.6497 - val_loss: 0.6642 - 29ms/epoch - 2ms/step
# Epoch 46/100
# 14/14 - 0s - loss: 0.6487 - val_loss: 0.6632 - 29ms/epoch - 2ms/step
# Epoch 47/100
# 14/14 - 0s - loss: 0.6470 - val_loss: 0.6625 - 29ms/epoch - 2ms/step
# Epoch 48/100
# 14/14 - 0s - loss: 0.6455 - val_loss: 0.6622 - 29ms/epoch - 2ms/step
# Epoch 49/100
# 14/14 - 0s - loss: 0.6439 - val_loss: 0.6608 - 29ms/epoch - 2ms/step
# Epoch 50/100
# 14/14 - 0s - loss: 0.6436 - val_loss: 0.6610 - 29ms/epoch - 2ms/step
# Epoch 51/100
# 14/14 - 0s - loss: 0.6417 - val_loss: 0.6586 - 29ms/epoch - 2ms/step
# Epoch 52/100
# 14/14 - 0s - loss: 0.6400 - val_loss: 0.6569 - 28ms/epoch - 2ms/step
# Epoch 53/100
# 14/14 - 0s - loss: 0.6389 - val_loss: 0.6553 - 29ms/epoch - 2ms/step
# Epoch 54/100
# 14/14 - 0s - loss: 0.6367 - val_loss: 0.6506 - 29ms/epoch - 2ms/step
# Epoch 55/100
# 14/14 - 0s - loss: 0.6308 - val_loss: 0.6465 - 29ms/epoch - 2ms/step
# Epoch 56/100
# 14/14 - 0s - loss: 0.6277 - val_loss: 0.6411 - 29ms/epoch - 2ms/step
# Epoch 57/100
# 14/14 - 0s - loss: 0.6234 - val_loss: 0.6317 - 28ms/epoch - 2ms/step
# Epoch 58/100
# 14/14 - 0s - loss: 0.6170 - val_loss: 0.6266 - 29ms/epoch - 2ms/step
# Epoch 59/100
# 14/14 - 0s - loss: 0.6088 - val_loss: 0.6136 - 31ms/epoch - 2ms/step
# Epoch 60/100
# 14/14 - 0s - loss: 0.6019 - val_loss: 0.6025 - 30ms/epoch - 2ms/step
# Epoch 61/100
# 14/14 - 0s - loss: 0.5917 - val_loss: 0.5909 - 29ms/epoch - 2ms/step
# Epoch 62/100
# 14/14 - 0s - loss: 0.5794 - val_loss: 0.5731 - 29ms/epoch - 2ms/step
# Epoch 63/100
# 14/14 - 0s - loss: 0.5693 - val_loss: 0.5583 - 30ms/epoch - 2ms/step
# Epoch 64/100
# 14/14 - 0s - loss: 0.5563 - val_loss: 0.5501 - 30ms/epoch - 2ms/step
# Epoch 65/100
# 14/14 - 0s - loss: 0.5445 - val_loss: 0.5233 - 30ms/epoch - 2ms/step
# Epoch 66/100
# 14/14 - 0s - loss: 0.5284 - val_loss: 0.5036 - 28ms/epoch - 2ms/step
# Epoch 67/100
# 14/14 - 0s - loss: 0.5142 - val_loss: 0.4892 - 30ms/epoch - 2ms/step
# Epoch 68/100
# 14/14 - 0s - loss: 0.4968 - val_loss: 0.4664 - 29ms/epoch - 2ms/step
# Epoch 69/100
# 14/14 - 0s - loss: 0.4811 - val_loss: 0.4535 - 30ms/epoch - 2ms/step
# Epoch 70/100
# 14/14 - 0s - loss: 0.4690 - val_loss: 0.4369 - 29ms/epoch - 2ms/step
# Epoch 71/100
# 14/14 - 0s - loss: 0.4515 - val_loss: 0.4178 - 29ms/epoch - 2ms/step
# Epoch 72/100
# 14/14 - 0s - loss: 0.4371 - val_loss: 0.4004 - 30ms/epoch - 2ms/step
# Epoch 73/100
# 14/14 - 0s - loss: 0.4236 - val_loss: 0.3840 - 29ms/epoch - 2ms/step
# Epoch 74/100
# 14/14 - 0s - loss: 0.4098 - val_loss: 0.3713 - 29ms/epoch - 2ms/step
# Epoch 75/100
# 14/14 - 0s - loss: 0.3929 - val_loss: 0.3597 - 29ms/epoch - 2ms/step
# Epoch 76/100
# 14/14 - 0s - loss: 0.3815 - val_loss: 0.3446 - 28ms/epoch - 2ms/step
# Epoch 77/100
# 14/14 - 0s - loss: 0.3690 - val_loss: 0.3354 - 29ms/epoch - 2ms/step
# Epoch 78/100
# 14/14 - 0s - loss: 0.3605 - val_loss: 0.3277 - 30ms/epoch - 2ms/step
# Epoch 79/100
# 14/14 - 0s - loss: 0.3564 - val_loss: 0.3201 - 30ms/epoch - 2ms/step
# Epoch 80/100
# 14/14 - 0s - loss: 0.3537 - val_loss: 0.3158 - 29ms/epoch - 2ms/step
# Epoch 81/100
# 14/14 - 0s - loss: 0.3514 - val_loss: 0.3076 - 29ms/epoch - 2ms/step
# Epoch 82/100
# 14/14 - 0s - loss: 0.3376 - val_loss: 0.3017 - 31ms/epoch - 2ms/step
# Epoch 83/100
# 14/14 - 0s - loss: 0.3294 - val_loss: 0.2976 - 31ms/epoch - 2ms/step
# Epoch 84/100
# 14/14 - 0s - loss: 0.3275 - val_loss: 0.2957 - 30ms/epoch - 2ms/step
# Epoch 85/100
# 14/14 - 0s - loss: 0.3271 - val_loss: 0.2906 - 30ms/epoch - 2ms/step
# Epoch 86/100
# 14/14 - 0s - loss: 0.3236 - val_loss: 0.2851 - 28ms/epoch - 2ms/step
# Epoch 87/100
# 14/14 - 0s - loss: 0.3143 - val_loss: 0.2825 - 30ms/epoch - 2ms/step
# Epoch 88/100
# 14/14 - 0s - loss: 0.3128 - val_loss: 0.2790 - 29ms/epoch - 2ms/step
# Epoch 89/100
# 14/14 - 0s - loss: 0.3092 - val_loss: 0.2784 - 28ms/epoch - 2ms/step
# Epoch 90/100
# 14/14 - 0s - loss: 0.3097 - val_loss: 0.2720 - 29ms/epoch - 2ms/step
# Epoch 91/100
# 14/14 - 0s - loss: 0.3034 - val_loss: 0.2682 - 30ms/epoch - 2ms/step
# Epoch 92/100
# 14/14 - 0s - loss: 0.3033 - val_loss: 0.2649 - 31ms/epoch - 2ms/step
# Epoch 93/100
# 14/14 - 0s - loss: 0.2992 - val_loss: 0.2638 - 28ms/epoch - 2ms/step
# Epoch 94/100
# 14/14 - 0s - loss: 0.2963 - val_loss: 0.2651 - 30ms/epoch - 2ms/step
# Epoch 95/100
# 14/14 - 0s - loss: 0.2972 - val_loss: 0.2571 - 31ms/epoch - 2ms/step
# Epoch 96/100
# 14/14 - 0s - loss: 0.2912 - val_loss: 0.2557 - 29ms/epoch - 2ms/step
# Epoch 97/100
# 14/14 - 0s - loss: 0.2903 - val_loss: 0.2519 - 31ms/epoch - 2ms/step
# Epoch 98/100
# 14/14 - 0s - loss: 0.2964 - val_loss: 0.2511 - 29ms/epoch - 2ms/step
# Epoch 99/100
# 14/14 - 0s - loss: 0.2934 - val_loss: 0.2493 - 29ms/epoch - 2ms/step
# Epoch 100/100
# 14/14 - 0s - loss: 0.2874 - val_loss: 0.2558 - 28ms/epoch - 2ms/step
# 2
# Epoch 1/100
# 14/14 - 0s - loss: 67.4724 - val_loss: 30.8992 - 470ms/epoch - 34ms/step
# Epoch 2/100
# 14/14 - 0s - loss: 11.0558 - val_loss: 0.9139 - 30ms/epoch - 2ms/step
# Epoch 3/100
# 14/14 - 0s - loss: 2.5449 - val_loss: 1.7934 - 30ms/epoch - 2ms/step
# Epoch 4/100
# 14/14 - 0s - loss: 1.3041 - val_loss: 0.2346 - 30ms/epoch - 2ms/step
# Epoch 5/100
# 14/14 - 0s - loss: 0.5871 - val_loss: 0.4258 - 31ms/epoch - 2ms/step
# Epoch 6/100
# 14/14 - 0s - loss: 0.5901 - val_loss: 0.1931 - 30ms/epoch - 2ms/step
# Epoch 7/100
# 14/14 - 0s - loss: 0.3706 - val_loss: 0.1704 - 39ms/epoch - 3ms/step
# Epoch 8/100
# 14/14 - 0s - loss: 0.3011 - val_loss: 0.1957 - 31ms/epoch - 2ms/step
# Epoch 9/100
# 14/14 - 0s - loss: 0.2779 - val_loss: 0.1973 - 28ms/epoch - 2ms/step
# Epoch 10/100
# 14/14 - 0s - loss: 0.2773 - val_loss: 0.2013 - 30ms/epoch - 2ms/step
# Epoch 11/100
# 14/14 - 0s - loss: 0.2672 - val_loss: 0.2004 - 39ms/epoch - 3ms/step
# Epoch 12/100
# 14/14 - 0s - loss: 0.2568 - val_loss: 0.1704 - 37ms/epoch - 3ms/step
# Epoch 12: early stopping
# 3
# Epoch 1/100
# 14/14 - 0s - loss: 213.3942 - val_loss: 160.3103 - 466ms/epoch - 33ms/step
# Epoch 2/100
# 14/14 - 0s - loss: 137.9929 - val_loss: 99.6400 - 33ms/epoch - 2ms/step
# Epoch 3/100
# 14/14 - 0s - loss: 75.2681 - val_loss: 38.8503 - 34ms/epoch - 2ms/step
# Epoch 4/100
# 14/14 - 0s - loss: 17.6294 - val_loss: 17.0859 - 31ms/epoch - 2ms/step
# Epoch 5/100
# 14/14 - 0s - loss: 7.9859 - val_loss: 4.8309 - 31ms/epoch - 2ms/step
# Epoch 6/100
# 14/14 - 0s - loss: 2.7350 - val_loss: 1.1383 - 37ms/epoch - 3ms/step
# Epoch 7/100
# 14/14 - 0s - loss: 1.0698 - val_loss: 0.7208 - 35ms/epoch - 3ms/step
# Epoch 8/100
# 14/14 - 0s - loss: 0.7101 - val_loss: 0.4913 - 30ms/epoch - 2ms/step
# Epoch 9/100
# 14/14 - 0s - loss: 0.5485 - val_loss: 0.3955 - 30ms/epoch - 2ms/step
# Epoch 10/100
# 14/14 - 0s - loss: 0.3596 - val_loss: 0.3137 - 30ms/epoch - 2ms/step
# Epoch 11/100
# 14/14 - 0s - loss: 0.2958 - val_loss: 0.2586 - 30ms/epoch - 2ms/step
# Epoch 12/100
# 14/14 - 0s - loss: 0.2821 - val_loss: 0.2415 - 30ms/epoch - 2ms/step
# Epoch 13/100
# 14/14 - 0s - loss: 0.2964 - val_loss: 0.2517 - 29ms/epoch - 2ms/step
# Epoch 14/100
# 14/14 - 0s - loss: 0.2712 - val_loss: 0.2437 - 30ms/epoch - 2ms/step
# Epoch 15/100
# 14/14 - 0s - loss: 0.2823 - val_loss: 0.2519 - 31ms/epoch - 2ms/step
# Epoch 16/100
# 14/14 - 0s - loss: 0.3134 - val_loss: 0.2434 - 33ms/epoch - 2ms/step
# Epoch 17/100
# 14/14 - 0s - loss: 0.2961 - val_loss: 0.2222 - 30ms/epoch - 2ms/step
# Epoch 18/100
# 14/14 - 0s - loss: 0.3244 - val_loss: 0.2149 - 31ms/epoch - 2ms/step
# Epoch 19/100
# 14/14 - 0s - loss: 0.2762 - val_loss: 0.2858 - 31ms/epoch - 2ms/step
# Epoch 20/100
# 14/14 - 0s - loss: 0.2986 - val_loss: 0.4510 - 34ms/epoch - 2ms/step
# Epoch 21/100
# 14/14 - 0s - loss: 0.3046 - val_loss: 0.2127 - 32ms/epoch - 2ms/step
# Epoch 22/100
# 14/14 - 0s - loss: 0.2724 - val_loss: 0.1946 - 31ms/epoch - 2ms/step
# Epoch 23/100
# 14/14 - 0s - loss: 0.2470 - val_loss: 0.2117 - 30ms/epoch - 2ms/step
# Epoch 24/100
# 14/14 - 0s - loss: 0.2419 - val_loss: 0.2465 - 29ms/epoch - 2ms/step
# Epoch 25/100
# 14/14 - 0s - loss: 0.3089 - val_loss: 0.3061 - 29ms/epoch - 2ms/step
# Epoch 26/100
# 14/14 - 0s - loss: 0.2889 - val_loss: 0.1843 - 30ms/epoch - 2ms/step
# Epoch 27/100
# 14/14 - 0s - loss: 0.2500 - val_loss: 0.2005 - 29ms/epoch - 2ms/step
# Epoch 28/100
# 14/14 - 0s - loss: 0.2364 - val_loss: 0.3121 - 30ms/epoch - 2ms/step
# Epoch 29/100
# 14/14 - 0s - loss: 0.2659 - val_loss: 0.1803 - 29ms/epoch - 2ms/step
# Epoch 30/100
# 14/14 - 0s - loss: 0.2542 - val_loss: 0.1916 - 30ms/epoch - 2ms/step
# Epoch 31/100
# 14/14 - 0s - loss: 0.2635 - val_loss: 0.1728 - 29ms/epoch - 2ms/step
# Epoch 32/100
# 14/14 - 0s - loss: 0.2680 - val_loss: 0.1728 - 29ms/epoch - 2ms/step
# Epoch 33/100
# 14/14 - 0s - loss: 0.2881 - val_loss: 0.1904 - 30ms/epoch - 2ms/step
# Epoch 34/100
# 14/14 - 0s - loss: 0.3134 - val_loss: 0.2549 - 29ms/epoch - 2ms/step
# Epoch 35/100
# 14/14 - 0s - loss: 0.3583 - val_loss: 0.1957 - 29ms/epoch - 2ms/step
# Epoch 36/100
# 14/14 - 0s - loss: 0.2901 - val_loss: 0.2077 - 30ms/epoch - 2ms/step
# Epoch 36: early stopping
# 4
# Epoch 1/100
# 14/14 - 0s - loss: 20.7649 - val_loss: 12.5289 - 480ms/epoch - 34ms/step
# Epoch 2/100
# 14/14 - 0s - loss: 6.4317 - val_loss: 3.2823 - 30ms/epoch - 2ms/step
# Epoch 3/100
# 14/14 - 0s - loss: 2.7854 - val_loss: 2.2093 - 30ms/epoch - 2ms/step
# Epoch 4/100
# 14/14 - 0s - loss: 1.6293 - val_loss: 1.0850 - 29ms/epoch - 2ms/step
# Epoch 5/100
# 14/14 - 0s - loss: 0.8030 - val_loss: 0.6832 - 52ms/epoch - 4ms/step
# Epoch 6/100
# 14/14 - 0s - loss: 0.6377 - val_loss: 0.6454 - 32ms/epoch - 2ms/step
# Epoch 7/100
# 14/14 - 0s - loss: 0.6015 - val_loss: 0.5941 - 30ms/epoch - 2ms/step
# Epoch 8/100
# 14/14 - 0s - loss: 0.5731 - val_loss: 0.5639 - 30ms/epoch - 2ms/step
# Epoch 9/100
# 14/14 - 0s - loss: 0.5643 - val_loss: 0.5472 - 29ms/epoch - 2ms/step
# Epoch 10/100
# 14/14 - 0s - loss: 0.5565 - val_loss: 0.5340 - 30ms/epoch - 2ms/step
# Epoch 11/100
# 14/14 - 0s - loss: 0.5481 - val_loss: 0.5210 - 30ms/epoch - 2ms/step
# Epoch 12/100
# 14/14 - 0s - loss: 0.5408 - val_loss: 0.5109 - 30ms/epoch - 2ms/step
# Epoch 13/100
# 14/14 - 0s - loss: 0.5335 - val_loss: 0.5018 - 32ms/epoch - 2ms/step
# Epoch 14/100
# 14/14 - 0s - loss: 0.5270 - val_loss: 0.4942 - 31ms/epoch - 2ms/step
# Epoch 15/100
# 14/14 - 0s - loss: 0.5207 - val_loss: 0.4857 - 31ms/epoch - 2ms/step
# Epoch 16/100
# 14/14 - 0s - loss: 0.5139 - val_loss: 0.4787 - 29ms/epoch - 2ms/step
# Epoch 17/100
# 14/14 - 0s - loss: 0.5076 - val_loss: 0.4717 - 29ms/epoch - 2ms/step
# Epoch 18/100
# 14/14 - 0s - loss: 0.5015 - val_loss: 0.4637 - 29ms/epoch - 2ms/step
# Epoch 19/100
# 14/14 - 0s - loss: 0.4950 - val_loss: 0.4575 - 30ms/epoch - 2ms/step
# Epoch 20/100
# 14/14 - 0s - loss: 0.4893 - val_loss: 0.4507 - 29ms/epoch - 2ms/step
# Epoch 21/100
# 14/14 - 0s - loss: 0.4830 - val_loss: 0.4444 - 29ms/epoch - 2ms/step
# Epoch 22/100
# 14/14 - 0s - loss: 0.4775 - val_loss: 0.4381 - 31ms/epoch - 2ms/step
# Epoch 23/100
# 14/14 - 0s - loss: 0.4718 - val_loss: 0.4321 - 29ms/epoch - 2ms/step
# Epoch 24/100
# 14/14 - 0s - loss: 0.4671 - val_loss: 0.4268 - 29ms/epoch - 2ms/step
# Epoch 25/100
# 14/14 - 0s - loss: 0.4608 - val_loss: 0.4204 - 30ms/epoch - 2ms/step
# Epoch 26/100
# 14/14 - 0s - loss: 0.4558 - val_loss: 0.4149 - 31ms/epoch - 2ms/step
# Epoch 27/100
# 14/14 - 0s - loss: 0.4507 - val_loss: 0.4097 - 32ms/epoch - 2ms/step
# Epoch 28/100
# 14/14 - 0s - loss: 0.4456 - val_loss: 0.4045 - 32ms/epoch - 2ms/step
# Epoch 29/100
# 14/14 - 0s - loss: 0.4406 - val_loss: 0.3988 - 30ms/epoch - 2ms/step
# Epoch 30/100
# 14/14 - 0s - loss: 0.4363 - val_loss: 0.3951 - 29ms/epoch - 2ms/step
# Epoch 31/100
# 14/14 - 0s - loss: 0.4311 - val_loss: 0.3884 - 29ms/epoch - 2ms/step
# Epoch 32/100
# 14/14 - 0s - loss: 0.4265 - val_loss: 0.3832 - 29ms/epoch - 2ms/step
# Epoch 33/100
# 14/14 - 0s - loss: 0.4223 - val_loss: 0.3803 - 30ms/epoch - 2ms/step
# Epoch 34/100
# 14/14 - 0s - loss: 0.4178 - val_loss: 0.3741 - 29ms/epoch - 2ms/step
# Epoch 35/100
# 14/14 - 0s - loss: 0.4141 - val_loss: 0.3696 - 29ms/epoch - 2ms/step
# Epoch 36/100
# 14/14 - 0s - loss: 0.4091 - val_loss: 0.3650 - 29ms/epoch - 2ms/step
# Epoch 37/100
# 14/14 - 0s - loss: 0.4044 - val_loss: 0.3608 - 29ms/epoch - 2ms/step
# Epoch 38/100
# 14/14 - 0s - loss: 0.4040 - val_loss: 0.3553 - 30ms/epoch - 2ms/step
# Epoch 39/100
# 14/14 - 0s - loss: 0.3971 - val_loss: 0.3536 - 29ms/epoch - 2ms/step
# Epoch 40/100
# 14/14 - 0s - loss: 0.3928 - val_loss: 0.3474 - 29ms/epoch - 2ms/step
# Epoch 41/100
# 14/14 - 0s - loss: 0.3909 - val_loss: 0.3440 - 28ms/epoch - 2ms/step
# Epoch 42/100
# 14/14 - 0s - loss: 0.3867 - val_loss: 0.3419 - 28ms/epoch - 2ms/step
# Epoch 43/100
# 14/14 - 0s - loss: 0.3823 - val_loss: 0.3363 - 29ms/epoch - 2ms/step
# Epoch 44/100
# 14/14 - 0s - loss: 0.3777 - val_loss: 0.3317 - 30ms/epoch - 2ms/step
# Epoch 45/100
# 14/14 - 0s - loss: 0.3763 - val_loss: 0.3281 - 29ms/epoch - 2ms/step
# Epoch 46/100
# 14/14 - 0s - loss: 0.3729 - val_loss: 0.3257 - 29ms/epoch - 2ms/step
# Epoch 47/100
# 14/14 - 0s - loss: 0.3678 - val_loss: 0.3206 - 30ms/epoch - 2ms/step
# Epoch 48/100
# 14/14 - 0s - loss: 0.3670 - val_loss: 0.3178 - 30ms/epoch - 2ms/step
# Epoch 49/100
# 14/14 - 0s - loss: 0.3635 - val_loss: 0.3158 - 28ms/epoch - 2ms/step
# Epoch 50/100
# 14/14 - 0s - loss: 0.3655 - val_loss: 0.3099 - 30ms/epoch - 2ms/step
# Epoch 51/100
# 14/14 - 0s - loss: 0.3559 - val_loss: 0.3105 - 41ms/epoch - 3ms/step
# Epoch 52/100
# 14/14 - 0s - loss: 0.3529 - val_loss: 0.3042 - 40ms/epoch - 3ms/step
# Epoch 53/100
# 14/14 - 0s - loss: 0.3499 - val_loss: 0.3004 - 31ms/epoch - 2ms/step
# Epoch 54/100
# 14/14 - 0s - loss: 0.3522 - val_loss: 0.3037 - 30ms/epoch - 2ms/step
# Epoch 55/100
# 14/14 - 0s - loss: 0.3439 - val_loss: 0.2938 - 30ms/epoch - 2ms/step
# Epoch 56/100
# 14/14 - 0s - loss: 0.3429 - val_loss: 0.2924 - 30ms/epoch - 2ms/step
# Epoch 57/100
# 14/14 - 0s - loss: 0.3399 - val_loss: 0.2921 - 30ms/epoch - 2ms/step
# Epoch 58/100
# 14/14 - 0s - loss: 0.3367 - val_loss: 0.2858 - 33ms/epoch - 2ms/step
# Epoch 59/100
# 14/14 - 0s - loss: 0.3345 - val_loss: 0.2836 - 31ms/epoch - 2ms/step
# Epoch 60/100
# 14/14 - 0s - loss: 0.3315 - val_loss: 0.2802 - 32ms/epoch - 2ms/step
# Epoch 61/100
# 14/14 - 0s - loss: 0.3328 - val_loss: 0.2807 - 32ms/epoch - 2ms/step
# Epoch 62/100
# 14/14 - 0s - loss: 0.3289 - val_loss: 0.2824 - 31ms/epoch - 2ms/step
# Epoch 63/100
# 14/14 - 0s - loss: 0.3266 - val_loss: 0.2725 - 30ms/epoch - 2ms/step
# Epoch 64/100
# 14/14 - 0s - loss: 0.3253 - val_loss: 0.2740 - 30ms/epoch - 2ms/step
# Epoch 65/100
# 14/14 - 0s - loss: 0.3218 - val_loss: 0.2688 - 29ms/epoch - 2ms/step
# Epoch 66/100
# 14/14 - 0s - loss: 0.3188 - val_loss: 0.2672 - 30ms/epoch - 2ms/step
# Epoch 67/100
# 14/14 - 0s - loss: 0.3170 - val_loss: 0.2632 - 29ms/epoch - 2ms/step
# Epoch 68/100
# 14/14 - 0s - loss: 0.3171 - val_loss: 0.2654 - 30ms/epoch - 2ms/step
# Epoch 69/100
# 14/14 - 0s - loss: 0.3143 - val_loss: 0.2583 - 30ms/epoch - 2ms/step
# Epoch 70/100
# 14/14 - 0s - loss: 0.3096 - val_loss: 0.2647 - 32ms/epoch - 2ms/step
# Epoch 71/100
# 14/14 - 0s - loss: 0.3116 - val_loss: 0.2557 - 32ms/epoch - 2ms/step
# Epoch 72/100
# 14/14 - 0s - loss: 0.3069 - val_loss: 0.2540 - 31ms/epoch - 2ms/step
# Epoch 73/100
# 14/14 - 0s - loss: 0.3092 - val_loss: 0.2489 - 30ms/epoch - 2ms/step
# Epoch 74/100
# 14/14 - 0s - loss: 0.3032 - val_loss: 0.2511 - 29ms/epoch - 2ms/step
# Epoch 75/100
# 14/14 - 0s - loss: 0.3038 - val_loss: 0.2442 - 30ms/epoch - 2ms/step
# Epoch 76/100
# 14/14 - 0s - loss: 0.3023 - val_loss: 0.2449 - 31ms/epoch - 2ms/step
# Epoch 77/100
# 14/14 - 0s - loss: 0.2985 - val_loss: 0.2438 - 29ms/epoch - 2ms/step
# Epoch 78/100
# 14/14 - 0s - loss: 0.2967 - val_loss: 0.2402 - 29ms/epoch - 2ms/step
# Epoch 79/100
# 14/14 - 0s - loss: 0.2949 - val_loss: 0.2414 - 30ms/epoch - 2ms/step
# Epoch 80/100
# 14/14 - 0s - loss: 0.2979 - val_loss: 0.2343 - 31ms/epoch - 2ms/step
# Epoch 81/100
# 14/14 - 0s - loss: 0.2918 - val_loss: 0.2386 - 32ms/epoch - 2ms/step
# Epoch 82/100
# 14/14 - 0s - loss: 0.2902 - val_loss: 0.2305 - 32ms/epoch - 2ms/step
# Epoch 83/100
# 14/14 - 0s - loss: 0.2907 - val_loss: 0.2309 - 32ms/epoch - 2ms/step
# Epoch 84/100
# 14/14 - 0s - loss: 0.2878 - val_loss: 0.2270 - 29ms/epoch - 2ms/step
# Epoch 85/100
# 14/14 - 0s - loss: 0.2892 - val_loss: 0.2271 - 30ms/epoch - 2ms/step
# Epoch 86/100
# 14/14 - 0s - loss: 0.2850 - val_loss: 0.2285 - 30ms/epoch - 2ms/step
# Epoch 87/100
# 14/14 - 0s - loss: 0.2830 - val_loss: 0.2217 - 30ms/epoch - 2ms/step
# Epoch 88/100
# 14/14 - 0s - loss: 0.2839 - val_loss: 0.2202 - 29ms/epoch - 2ms/step
# Epoch 89/100
# 14/14 - 0s - loss: 0.2809 - val_loss: 0.2185 - 30ms/epoch - 2ms/step
# Epoch 90/100
# 14/14 - 0s - loss: 0.2792 - val_loss: 0.2166 - 30ms/epoch - 2ms/step
# Epoch 91/100
# 14/14 - 0s - loss: 0.2764 - val_loss: 0.2158 - 29ms/epoch - 2ms/step
# Epoch 92/100
# 14/14 - 0s - loss: 0.2744 - val_loss: 0.2125 - 40ms/epoch - 3ms/step
# Epoch 93/100
# 14/14 - 0s - loss: 0.2768 - val_loss: 0.2112 - 38ms/epoch - 3ms/step
# Epoch 94/100
# 14/14 - 0s - loss: 0.2794 - val_loss: 0.2114 - 30ms/epoch - 2ms/step
# Epoch 95/100
# 14/14 - 0s - loss: 0.2723 - val_loss: 0.2133 - 29ms/epoch - 2ms/step
# Epoch 96/100
# 14/14 - 0s - loss: 0.2738 - val_loss: 0.2086 - 29ms/epoch - 2ms/step
# Epoch 97/100
# 14/14 - 0s - loss: 0.2693 - val_loss: 0.2046 - 29ms/epoch - 2ms/step
# Epoch 98/100
# 14/14 - 0s - loss: 0.2718 - val_loss: 0.2135 - 30ms/epoch - 2ms/step
# Epoch 99/100
# 14/14 - 0s - loss: 0.2678 - val_loss: 0.2012 - 29ms/epoch - 2ms/step
# Epoch 100/100
# 14/14 - 0s - loss: 0.2689 - val_loss: 0.1998 - 29ms/epoch - 2ms/step
# Training finished...Loading the best model
#
# 5/5 [==============================] - 0s 1ms/step
# Final accuracy: 0.9440559440559441

# %% [markdown]
# ### Confusion Matrix
#
# The confusion matrix is a common visualization for both binary and multi-class classification problems.  The following code generates a confusion matrix:

# %%
import numpy as np

from sklearn import svm, datasets
from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix, classification_report

# Compute confusion matrix
cm = confusion_matrix(y_true, pred)
print(cm)


print('Plotting confusion matrix')

plt.figure()
plot_confusion_matrix(cm, diagnosis)
plt.show()

print(classification_report(y_true, pred))
# Out:
# [[89  0]
#  [ 8 46]]
# Plotting confusion matrix
#               precision    recall  f1-score   support
#
#            0       0.92      1.00      0.96        89
#            1       1.00      0.85      0.92        54
#
#     accuracy                           0.94       143
#    macro avg       0.96      0.93      0.94       143
# weighted avg       0.95      0.94      0.94       143

# %% [markdown]
# ### ROC Curves
#
# **An ROC curve measures how good a model is regardless of the cutoff.**
#
# The following code shows an ROC chart for the breast cancer neural network.  The area under the curve (AUC) is also an important measure.  The larger the AUC, the better.

# %%
pred = model.predict(x_test)
pred = pred[:,1] # Only positive class (M)
plot_roc(pred,y_true)
# Out:
# 5/5 [==============================] - 0s 1000us/step

# %% [markdown]
# # Visualizing multi-class classification models
#
# We've already seen multi-class classification, with the iris dataset.  Confusion matrixes work just fine with 3 classes.  The following code generates a confusion matrix for iris.

# %%
import pandas as pd
import io
import requests
import numpy as np
import os
from sklearn.model_selection import train_test_split
from sklearn import metrics
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Activation
from tensorflow.keras.callbacks import EarlyStopping
from tensorflow.keras.callbacks import ModelCheckpoint

path = "./data/"
    
filename = os.path.join(path,"iris.csv")    
df = pd.read_csv(filename,na_values=['NA','?'])

species = encode_text_index(df,"species")
x,y = to_xy(df,"species")

# Split into train/test
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.25, random_state=42)

model = Sequential()
model.add(Dense(20, input_dim=x.shape[1], activation='relu'))
model.add(Dense(10))
model.add(Dense(y.shape[1],activation='softmax'))
model.compile(loss='categorical_crossentropy', optimizer='adam')

monitor = EarlyStopping(monitor='val_loss', min_delta=1e-3, patience=5, verbose=0, mode='auto')
checkpointer = ModelCheckpoint(filepath="dnn/best_weights.hdf5", verbose=0, save_best_only=True) # save best model

model.fit(x_train,y_train,validation_data=(x_test,y_test),callbacks=[monitor,checkpointer],verbose=2,epochs=100)

model.load_weights('dnn/best_weights.hdf5') # load weights from best model
# Out:
# Epoch 1/100
# 4/4 - 0s - loss: 1.3757 - val_loss: 1.4562 - 477ms/epoch - 119ms/step
# Epoch 2/100
# 4/4 - 0s - loss: 1.2982 - val_loss: 1.3543 - 37ms/epoch - 9ms/step
# Epoch 3/100
# 4/4 - 0s - loss: 1.2231 - val_loss: 1.2722 - 36ms/epoch - 9ms/step
# Epoch 4/100
# 4/4 - 0s - loss: 1.1744 - val_loss: 1.2036 - 34ms/epoch - 8ms/step
# Epoch 5/100
# 4/4 - 0s - loss: 1.1288 - val_loss: 1.1520 - 32ms/epoch - 8ms/step
# Epoch 6/100
# 4/4 - 0s - loss: 1.0954 - val_loss: 1.1098 - 32ms/epoch - 8ms/step
# c:\Users\cdub6\anaconda3\Lib\site-packages\keras\src\engine\training.py:3103: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
# Epoch 7/100
# 4/4 - 0s - loss: 1.0667 - val_loss: 1.0739 - 33ms/epoch - 8ms/step
# Epoch 8/100
# 4/4 - 0s - loss: 1.0432 - val_loss: 1.0412 - 32ms/epoch - 8ms/step
# Epoch 9/100
# 4/4 - 0s - loss: 1.0180 - val_loss: 1.0133 - 31ms/epoch - 8ms/step
# Epoch 10/100
# 4/4 - 0s - loss: 0.9935 - val_loss: 0.9880 - 32ms/epoch - 8ms/step
# Epoch 11/100
# 4/4 - 0s - loss: 0.9714 - val_loss: 0.9634 - 32ms/epoch - 8ms/step
# Epoch 12/100
# 4/4 - 0s - loss: 0.9501 - val_loss: 0.9381 - 35ms/epoch - 9ms/step
# Epoch 13/100
# 4/4 - 0s - loss: 0.9273 - val_loss: 0.9134 - 35ms/epoch - 9ms/step
# Epoch 14/100
# 4/4 - 0s - loss: 0.9056 - val_loss: 0.8897 - 35ms/epoch - 9ms/step
# Epoch 15/100
# 4/4 - 0s - loss: 0.8848 - val_loss: 0.8658 - 32ms/epoch - 8ms/step
# Epoch 16/100
# 4/4 - 0s - loss: 0.8631 - val_loss: 0.8417 - 33ms/epoch - 8ms/step
# Epoch 17/100
# 4/4 - 0s - loss: 0.8426 - val_loss: 0.8176 - 32ms/epoch - 8ms/step
# Epoch 18/100
# 4/4 - 0s - loss: 0.8216 - val_loss: 0.7947 - 32ms/epoch - 8ms/step
# Epoch 19/100
# 4/4 - 0s - loss: 0.8008 - val_loss: 0.7713 - 33ms/epoch - 8ms/step
# Epoch 20/100
# 4/4 - 0s - loss: 0.7825 - val_loss: 0.7473 - 34ms/epoch - 9ms/step
# Epoch 21/100
# 4/4 - 0s - loss: 0.7621 - val_loss: 0.7259 - 32ms/epoch - 8ms/step
# Epoch 22/100
# 4/4 - 0s - loss: 0.7422 - val_loss: 0.7047 - 33ms/epoch - 8ms/step
# Epoch 23/100
# 4/4 - 0s - loss: 0.7233 - val_loss: 0.6829 - 35ms/epoch - 9ms/step
# Epoch 24/100
# 4/4 - 0s - loss: 0.7044 - val_loss: 0.6620 - 35ms/epoch - 9ms/step
# Epoch 25/100
# 4/4 - 0s - loss: 0.6862 - val_loss: 0.6418 - 33ms/epoch - 8ms/step
# Epoch 26/100
# 4/4 - 0s - loss: 0.6692 - val_loss: 0.6219 - 33ms/epoch - 8ms/step
# Epoch 27/100
# 4/4 - 0s - loss: 0.6526 - val_loss: 0.6031 - 32ms/epoch - 8ms/step
# Epoch 28/100
# 4/4 - 0s - loss: 0.6363 - val_loss: 0.5859 - 32ms/epoch - 8ms/step
# Epoch 29/100
# 4/4 - 0s - loss: 0.6205 - val_loss: 0.5701 - 31ms/epoch - 8ms/step
# Epoch 30/100
# 4/4 - 0s - loss: 0.6064 - val_loss: 0.5547 - 32ms/epoch - 8ms/step
# Epoch 31/100
# 4/4 - 0s - loss: 0.5926 - val_loss: 0.5409 - 32ms/epoch - 8ms/step
# Epoch 32/100
# 4/4 - 0s - loss: 0.5800 - val_loss: 0.5277 - 32ms/epoch - 8ms/step
# Epoch 33/100
# 4/4 - 0s - loss: 0.5679 - val_loss: 0.5156 - 34ms/epoch - 9ms/step
# Epoch 34/100
# 4/4 - 0s - loss: 0.5567 - val_loss: 0.5044 - 36ms/epoch - 9ms/step
# Epoch 35/100
# 4/4 - 0s - loss: 0.5461 - val_loss: 0.4935 - 51ms/epoch - 13ms/step
# Epoch 36/100
# 4/4 - 0s - loss: 0.5363 - val_loss: 0.4832 - 34ms/epoch - 8ms/step
# Epoch 37/100
# 4/4 - 0s - loss: 0.5265 - val_loss: 0.4732 - 32ms/epoch - 8ms/step
# Epoch 38/100
# 4/4 - 0s - loss: 0.5174 - val_loss: 0.4641 - 32ms/epoch - 8ms/step
# Epoch 39/100
# 4/4 - 0s - loss: 0.5093 - val_loss: 0.4554 - 33ms/epoch - 8ms/step
# Epoch 40/100
# 4/4 - 0s - loss: 0.5021 - val_loss: 0.4465 - 31ms/epoch - 8ms/step
# Epoch 41/100
# 4/4 - 0s - loss: 0.4927 - val_loss: 0.4387 - 33ms/epoch - 8ms/step
# Epoch 42/100
# 4/4 - 0s - loss: 0.4845 - val_loss: 0.4312 - 33ms/epoch - 8ms/step
# Epoch 43/100
# 4/4 - 0s - loss: 0.4769 - val_loss: 0.4242 - 33ms/epoch - 8ms/step
# Epoch 44/100
# 4/4 - 0s - loss: 0.4697 - val_loss: 0.4174 - 31ms/epoch - 8ms/step
# Epoch 45/100
# 4/4 - 0s - loss: 0.4633 - val_loss: 0.4113 - 33ms/epoch - 8ms/step
# Epoch 46/100
# 4/4 - 0s - loss: 0.4567 - val_loss: 0.4050 - 34ms/epoch - 8ms/step
# Epoch 47/100
# 4/4 - 0s - loss: 0.4494 - val_loss: 0.3973 - 31ms/epoch - 8ms/step
# Epoch 48/100
# 4/4 - 0s - loss: 0.4423 - val_loss: 0.3907 - 33ms/epoch - 8ms/step
# Epoch 49/100
# 4/4 - 0s - loss: 0.4367 - val_loss: 0.3845 - 31ms/epoch - 8ms/step
# Epoch 50/100
# 4/4 - 0s - loss: 0.4307 - val_loss: 0.3785 - 33ms/epoch - 8ms/step
# Epoch 51/100
# 4/4 - 0s - loss: 0.4241 - val_loss: 0.3728 - 34ms/epoch - 8ms/step
# Epoch 52/100
# 4/4 - 0s - loss: 0.4182 - val_loss: 0.3673 - 35ms/epoch - 9ms/step
# Epoch 53/100
# 4/4 - 0s - loss: 0.4127 - val_loss: 0.3618 - 32ms/epoch - 8ms/step
# Epoch 54/100
# 4/4 - 0s - loss: 0.4065 - val_loss: 0.3568 - 31ms/epoch - 8ms/step
# Epoch 55/100
# 4/4 - 0s - loss: 0.4004 - val_loss: 0.3522 - 30ms/epoch - 7ms/step
# Epoch 56/100
# 4/4 - 0s - loss: 0.3953 - val_loss: 0.3481 - 32ms/epoch - 8ms/step
# Epoch 57/100
# 4/4 - 0s - loss: 0.3928 - val_loss: 0.3445 - 31ms/epoch - 8ms/step
# Epoch 58/100
# 4/4 - 0s - loss: 0.3867 - val_loss: 0.3375 - 31ms/epoch - 8ms/step
# Epoch 59/100
# 4/4 - 0s - loss: 0.3794 - val_loss: 0.3321 - 30ms/epoch - 7ms/step
# Epoch 60/100
# 4/4 - 0s - loss: 0.3741 - val_loss: 0.3269 - 31ms/epoch - 8ms/step
# Epoch 61/100
# 4/4 - 0s - loss: 0.3690 - val_loss: 0.3218 - 32ms/epoch - 8ms/step
# Epoch 62/100
# 4/4 - 0s - loss: 0.3646 - val_loss: 0.3169 - 34ms/epoch - 9ms/step
# Epoch 63/100
# 4/4 - 0s - loss: 0.3588 - val_loss: 0.3119 - 33ms/epoch - 8ms/step
# Epoch 64/100
# 4/4 - 0s - loss: 0.3541 - val_loss: 0.3072 - 31ms/epoch - 8ms/step
# Epoch 65/100
# 4/4 - 0s - loss: 0.3492 - val_loss: 0.3027 - 31ms/epoch - 8ms/step
# Epoch 66/100
# 4/4 - 0s - loss: 0.3451 - val_loss: 0.2981 - 32ms/epoch - 8ms/step
# Epoch 67/100
# 4/4 - 0s - loss: 0.3393 - val_loss: 0.2937 - 30ms/epoch - 7ms/step
# Epoch 68/100
# 4/4 - 0s - loss: 0.3346 - val_loss: 0.2895 - 30ms/epoch - 7ms/step
# Epoch 69/100
# 4/4 - 0s - loss: 0.3309 - val_loss: 0.2860 - 32ms/epoch - 8ms/step
# Epoch 70/100
# 4/4 - 0s - loss: 0.3254 - val_loss: 0.2818 - 30ms/epoch - 8ms/step
# Epoch 71/100
# 4/4 - 0s - loss: 0.3204 - val_loss: 0.2773 - 30ms/epoch - 7ms/step
# Epoch 72/100
# 4/4 - 0s - loss: 0.3162 - val_loss: 0.2732 - 34ms/epoch - 9ms/step
# Epoch 73/100
# 4/4 - 0s - loss: 0.3148 - val_loss: 0.2694 - 34ms/epoch - 8ms/step
# Epoch 74/100
# 4/4 - 0s - loss: 0.3079 - val_loss: 0.2659 - 32ms/epoch - 8ms/step
# Epoch 75/100
# 4/4 - 0s - loss: 0.3029 - val_loss: 0.2623 - 37ms/epoch - 9ms/step
# Epoch 76/100
# 4/4 - 0s - loss: 0.2988 - val_loss: 0.2585 - 41ms/epoch - 10ms/step
# Epoch 77/100
# 4/4 - 0s - loss: 0.2949 - val_loss: 0.2545 - 32ms/epoch - 8ms/step
# Epoch 78/100
# 4/4 - 0s - loss: 0.2918 - val_loss: 0.2499 - 31ms/epoch - 8ms/step
# Epoch 79/100
# 4/4 - 0s - loss: 0.2863 - val_loss: 0.2462 - 31ms/epoch - 8ms/step
# Epoch 80/100
# 4/4 - 0s - loss: 0.2829 - val_loss: 0.2425 - 33ms/epoch - 8ms/step
# Epoch 81/100
# 4/4 - 0s - loss: 0.2786 - val_loss: 0.2387 - 33ms/epoch - 8ms/step
# Epoch 82/100
# 4/4 - 0s - loss: 0.2747 - val_loss: 0.2351 - 35ms/epoch - 9ms/step
# Epoch 83/100
# 4/4 - 0s - loss: 0.2702 - val_loss: 0.2316 - 33ms/epoch - 8ms/step
# Epoch 84/100
# 4/4 - 0s - loss: 0.2668 - val_loss: 0.2289 - 31ms/epoch - 8ms/step
# Epoch 85/100
# 4/4 - 0s - loss: 0.2630 - val_loss: 0.2257 - 31ms/epoch - 8ms/step
# Epoch 86/100
# 4/4 - 0s - loss: 0.2592 - val_loss: 0.2219 - 31ms/epoch - 8ms/step
# Epoch 87/100
# 4/4 - 0s - loss: 0.2552 - val_loss: 0.2186 - 31ms/epoch - 8ms/step
# Epoch 88/100
# 4/4 - 0s - loss: 0.2532 - val_loss: 0.2149 - 31ms/epoch - 8ms/step
# Epoch 89/100
# 4/4 - 0s - loss: 0.2483 - val_loss: 0.2118 - 30ms/epoch - 7ms/step
# Epoch 90/100
# 4/4 - 0s - loss: 0.2442 - val_loss: 0.2094 - 33ms/epoch - 8ms/step
# Epoch 91/100
# 4/4 - 0s - loss: 0.2413 - val_loss: 0.2072 - 34ms/epoch - 8ms/step
# Epoch 92/100
# 4/4 - 0s - loss: 0.2383 - val_loss: 0.2040 - 32ms/epoch - 8ms/step
# Epoch 93/100
# 4/4 - 0s - loss: 0.2347 - val_loss: 0.2001 - 32ms/epoch - 8ms/step
# Epoch 94/100
# 4/4 - 0s - loss: 0.2310 - val_loss: 0.1967 - 31ms/epoch - 8ms/step
# Epoch 95/100
# 4/4 - 0s - loss: 0.2280 - val_loss: 0.1938 - 30ms/epoch - 8ms/step
# Epoch 96/100
# 4/4 - 0s - loss: 0.2251 - val_loss: 0.1909 - 33ms/epoch - 8ms/step
# Epoch 97/100
# 4/4 - 0s - loss: 0.2216 - val_loss: 0.1888 - 31ms/epoch - 8ms/step
# Epoch 98/100
# 4/4 - 0s - loss: 0.2184 - val_loss: 0.1875 - 30ms/epoch - 7ms/step
# Epoch 99/100
# 4/4 - 0s - loss: 0.2168 - val_loss: 0.1850 - 32ms/epoch - 8ms/step
# Epoch 100/100
# 4/4 - 0s - loss: 0.2140 - val_loss: 0.1804 - 32ms/epoch - 8ms/step

# %%
import numpy as np

from sklearn import svm, datasets
from sklearn.metrics import confusion_matrix, classification_report

pred = model.predict(x_test)
pred = np.argmax(pred,axis=1)
y_true = np.argmax(y_test,axis=1)
    
# Compute confusion matrix
cm = confusion_matrix(y_true, pred)
print(cm)

print('Ploting confusion matrix')
plt.figure()
plot_confusion_matrix(cm, species)
plt.show()


print(classification_report(y_true, pred))
# Out:
# 2/2 [==============================] - 0s 1ms/step
# [[15  0  0]
#  [ 0 11  0]
#  [ 0  0 12]]
# Ploting confusion matrix
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00        15
#            1       1.00      1.00      1.00        11
#            2       1.00      1.00      1.00        12
#
#     accuracy                           1.00        38
#    macro avg       1.00      1.00      1.00        38
# weighted avg       1.00      1.00      1.00        38

# %% [markdown]
# # Visualizing regression models
#
# We've already seen regression with the MPG dataset.  Regression uses its own set of visualizations, one of the most common is the lift chart.  The following code generates a lift chart.

# %%
# %matplotlib inline
from matplotlib.pyplot import figure, show
from sklearn.model_selection import train_test_split
import pandas as pd
import numpy as np
from sklearn import metrics
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Activation
from tensorflow.keras.callbacks import EarlyStopping
from tensorflow.keras.callbacks import ModelCheckpoint


path = "./data/"
preprocess = False

filename_read = os.path.join(path,"auto-mpg.csv")
df = pd.read_csv(filename_read,na_values=['NA','?'])

# create feature vector
missing_median(df, 'horsepower')
encode_text_dummy(df, 'origin')
df.drop('name', axis=1,inplace=True)
if preprocess:
    encode_numeric_zscore(df, 'horsepower')
    encode_numeric_zscore(df, 'weight')
    encode_numeric_zscore(df, 'cylinders')
    encode_numeric_zscore(df, 'displacement')
    encode_numeric_zscore(df, 'acceleration')
    encode_numeric_zscore(df, 'year')

# Encode to a 2D matrix for training
x,y = to_xy(df,'mpg')

# Split into train/test
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.20, random_state=42)

model = Sequential()
model.add(Dense(100, input_dim=x.shape[1], activation='relu'))      # try changing 100 to 10
model.add(Dense(10, activation='relu'))
model.add(Dense(1))

model.compile(loss='mean_squared_error', optimizer='adam')

monitor = EarlyStopping(monitor='val_loss', min_delta=1e-3, patience=5, verbose=1, mode='auto')

checkpointer = ModelCheckpoint(filepath="dnn/best_weights.hdf5", verbose=0, save_best_only=True) # save best model

model.fit(x_train,y_train,validation_data=(x_test,y_test),callbacks=[monitor,checkpointer],verbose=2,epochs=500)

model.load_weights('dnn/best_weights.hdf5') # load weights from best model

# Predict and measure RMSE
pred = model.predict(x_test)

score = np.sqrt(metrics.mean_squared_error(pred,y_test))
print("Score (RMSE): {}".format(score))

# Plot the chart
chart_regression(pred.flatten(),y_test, sort= True)
# Out:
# Epoch 1/500
# 10/10 - 1s - loss: 2903.4792 - val_loss: 395.6825 - 516ms/epoch - 52ms/step
# Epoch 2/500
# 10/10 - 0s - loss: 250.2036 - val_loss: 196.0124 - 38ms/epoch - 4ms/step
# Epoch 3/500
# 10/10 - 0s - loss: 200.0826 - val_loss: 146.6717 - 36ms/epoch - 4ms/step
# Epoch 4/500
# 10/10 - 0s - loss: 162.5552 - val_loss: 150.7139 - 30ms/epoch - 3ms/step
# Epoch 5/500
# 10/10 - 0s - loss: 159.5386 - val_loss: 129.4798 - 40ms/epoch - 4ms/step
# Epoch 6/500
# 10/10 - 0s - loss: 150.3623 - val_loss: 120.0376 - 38ms/epoch - 4ms/step
# c:\Users\cdub6\anaconda3\Lib\site-packages\keras\src\engine\training.py:3103: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
# Epoch 7/500
# 10/10 - 0s - loss: 142.5791 - val_loss: 118.3726 - 39ms/epoch - 4ms/step
# Epoch 8/500
# 10/10 - 0s - loss: 135.5707 - val_loss: 129.3783 - 27ms/epoch - 3ms/step
# Epoch 9/500
# 10/10 - 0s - loss: 128.7512 - val_loss: 101.8196 - 37ms/epoch - 4ms/step
# Epoch 10/500
# 10/10 - 0s - loss: 110.7894 - val_loss: 94.3261 - 35ms/epoch - 3ms/step
# Epoch 11/500
# 10/10 - 0s - loss: 110.4564 - val_loss: 117.1170 - 26ms/epoch - 3ms/step
# Epoch 12/500
# 10/10 - 0s - loss: 103.0375 - val_loss: 78.6188 - 35ms/epoch - 4ms/step
# Epoch 13/500
# 10/10 - 0s - loss: 95.8731 - val_loss: 71.3420 - 38ms/epoch - 4ms/step
# Epoch 14/500
# 10/10 - 0s - loss: 89.9201 - val_loss: 67.8267 - 37ms/epoch - 4ms/step
# Epoch 15/500
# 10/10 - 0s - loss: 85.9777 - val_loss: 63.3135 - 37ms/epoch - 4ms/step
# Epoch 16/500
# 10/10 - 0s - loss: 83.0029 - val_loss: 67.1516 - 27ms/epoch - 3ms/step
# Epoch 17/500
# 10/10 - 0s - loss: 79.0651 - val_loss: 68.7442 - 27ms/epoch - 3ms/step
# Epoch 18/500
# 10/10 - 0s - loss: 76.4304 - val_loss: 79.4267 - 26ms/epoch - 3ms/step
# Epoch 19/500
# 10/10 - 0s - loss: 79.1479 - val_loss: 115.9859 - 26ms/epoch - 3ms/step
# Epoch 20/500
# 10/10 - 0s - loss: 86.9150 - val_loss: 65.5116 - 27ms/epoch - 3ms/step
# Epoch 20: early stopping
# 3/3 [==============================] - 0s 999us/step
# Score (RMSE): 7.956975936889648

# %% [markdown]
# The lift chart as shown above was achieved by performing the following actions:
#
# * Sort the data by expected output.  Plot the blue line above.  Blue line is always increasing.
# * For every point on the x-axis plot the predicted value for that same data point.  This is the orange line above.
# * The x-axis is the index of test data after sorting.  The index always starts low and ends high.
#
# Reading a lift chart:
# * The expected and predict lines should be close.  Notice where one is above the other.
# * The above chart is the most accurate on lower MPG.

# %% [markdown]
# #### Regression lift chart without sorting on expected output (y_test)

# %%
chart_regression(pred.flatten(),y_test,sort=False)

# %% [markdown]
# ### References:
#
# * [Google Colab](https://colab.research.google.com/) - Free web based platform that includes Python, Juypter Notebooks, and TensorFlow with free GPU support.  No setup needed.
# * [IBM Cognitive Class Labs](https://www.datascientistworkbench.com) - Free web based platform that includes Python, Juypter Notebooks, and TensorFlow.  No setup needed.
# * [Python Anaconda](https://www.continuum.io/downloads) - Python distribution that includes many data science packages, such as Numpy, Scipy, Scikit-Learn, Pandas, and much more.
# * [TensorFlow](https://www.tensorflow.org/) - Google's mathematics package for deep learning.
# * [Kaggle](https://www.kaggle.com/) - Competitive data science.  Good source of sample data.
# * T81-558: Applications of Deep Neural Networks. Instructor: [Jeff Heaton](https://sites.wustl.edu/jeffheaton/)
